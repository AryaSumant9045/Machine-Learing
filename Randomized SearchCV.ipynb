# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

X, y = make_classification(
    n_features=10, 
    n_samples=1000, 
    n_informative=8,
    n_redundant=2,
    n_repeated=0,
    n_classes=2, 
    random_state=42
)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

clf = GridSearchCV(
    DecisionTreeClassifier(),
    {'criterion': ["gini", "entropy"],'max_depth': [5, 10, 15, 20]},
    cv=5,
    return_train_score=False
)
clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009696      0.000630         0.001274        0.000390
# 1       0.016734      0.002780         0.002055        0.000961
# 2       0.016152      0.001461         0.001134        0.000213
# 3       0.032116      0.008556         0.002890        0.000461
# 4       0.026170      0.014872         0.001595        0.000749
# 5       0.022541      0.001955         0.001611        0.000509
# 6       0.023784      0.003331         0.001150        0.000423
# 7       0.027726      0.001730         0.001603        0.000494
#
#   param_criterion  param_max_depth                                     params  \
# 0            gini                5      {'criterion': 'gini', 'max_depth': 5}
# 1            gini               10     {'criterion': 'gini', 'max_depth': 10}
# 2            gini               15     {'criterion': 'gini', 'max_depth': 15}
# 3            gini               20     {'criterion': 'gini', 'max_depth': 20}
# 4         entropy                5   {'criterion': 'entropy', 'max_depth': 5}
# 5         entropy               10  {'criterion': 'entropy', 'max_depth': 10}
# 6         entropy               15  {'criterion': 'entropy', 'max_depth': 15}
# 7         entropy               20  {'criterion': 'entropy', 'max_depth': 20}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.780              0.800              0.735               0.80
# 1              0.760              0.735              0.810               0.78
# 2              0.790              0.730              0.805               0.82
# 3              0.815              0.705              0.805               0.81
# 4              0.765              0.780              0.750               0.81
# 5              0.770              0.775              0.845               0.78
# 6              0.750              0.795              0.820               0.80
# 7              0.775              0.800              0.825               0.80
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.770            0.777        0.024000                7
# 1              0.810            0.779        0.029052                6
# 2              0.820            0.793        0.033407                3
# 3              0.820            0.791        0.043290                4
# 4              0.775            0.776        0.019849                8
# 5              0.785            0.791        0.027459                4
# 6              0.870            0.807        0.038936                2
# 7              0.870            0.814        0.032156                1

# %%
from sklearn.model_selection import RandomizedSearchCV

clf = RandomizedSearchCV(
    DecisionTreeClassifier(),
    {'criterion': ["gini", "entropy"],'max_depth': [5, 10, 15, 20]},
    cv=5,
    return_train_score=False,
    n_iter=3 
)
clf.fit(X, y)
df = pd.DataFrame(clf.cv_results_)
df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.028054      0.015115         0.002304    4.072057e-04
# 1       0.021939      0.003567         0.000999    3.568323e-07
# 2       0.023806      0.004019         0.001334    4.239701e-04
#
#    param_max_depth param_criterion                                     params  \
# 0               10            gini     {'max_depth': 10, 'criterion': 'gini'}
# 1               20         entropy  {'max_depth': 20, 'criterion': 'entropy'}
# 2               15         entropy  {'max_depth': 15, 'criterion': 'entropy'}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0              0.770              0.725              0.790              0.800
# 1              0.760              0.805              0.820              0.800
# 2              0.765              0.805              0.825              0.785
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0               0.81            0.779        0.030067                3
# 1               0.86            0.809        0.032311                2
# 2               0.87            0.810        0.036056                1

# %%
clf.best_params_
# Out:
# {'max_depth': 15, 'criterion': 'entropy'}
